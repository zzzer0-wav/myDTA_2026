# %% [markdown]
# <a href="https://colab.research.google.com/github/zzzer0-wav/myDTA_2026/blob/main/classmade/PANDAS_lecture_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas: знайомство з аналізом даних
#
# **Лекція • 1.5 години**
#
# ---
#
# ## Що таке pandas?
#
# **pandas** — це найпопулярніша бібліотека Python для роботи з табличними даними. Якщо ви працювали з Excel або Google Sheets — pandas це те саме, але:
# - 🚀 значно швидше на великих даних
# - 🔁 усе автоматизується кодом (не треба клікати мишкою)
# - 🔗 легко поєднується з графіками, машинним навчанням, базами даних
#
# Головний об'єкт у pandas — це **DataFrame** (таблиця з рядками і стовпцями).
#
# > 💡 **Як працювати з зошитом:** запускайте кожну комірку по черзі (Shift + Enter) і дивіться на результат. Експериментуйте — змінюйте код і дивіться, що зміниться!
#
# ---

# %% [markdown]
# ## 1. Імпорт бібліотеки
#
# За традицією pandas імпортують зі скороченням `pd`. Це загальноприйнято — так пишуть усі.

# %%
import pandas as pd

print("pandas версія:", pd.__version__)
# Out:
# pandas версія: 2.2.2

# %% [markdown]
# ## 2. Завантаження даних
#
# Сьогодні ми працюємо з даними мережі кав'ярень — це файл `coffee_sales.csv` з замовленнями за 6 місяців.
#
# Щоб прочитати CSV-файл, використовуємо `pd.read_csv()`. Результат — це DataFrame, який ми зазвичай зберігаємо у змінну `df`.

# %%
df = pd.read_csv("coffee_sales.csv")

# .head() показує перші 5 рядків
df.head()
# Out:
#    order_id        date    city   product category  unit_price  quantity  \
# 0      1255  2024-05-21   Львів      Лате    Напої          70         2
# 1      1299  2024-05-25  Харків       Чай    Напої          40         2
# 2      1003  2024-01-14  Харків    Маффін  Випічка          60         1
# 3      1226  2024-04-21   Львів  Капучіно    Напої          65         1
# 4      1114  2024-02-16   Львів      Лате    Напої          70         1
#
#    discount_pct  revenue manager
# 0             0    140.0   Олена
# 1             5     76.0  Богдан
# 2             0     60.0   Олена
# 3             0     65.0   Олена
# 4            10     63.0  Андрій

# %% [markdown]
# ### Перший погляд на дані
#
# Кілька найкорисніших команд для знайомства з новим датасетом:

# %%
# Розмір таблиці: (рядки, стовпці)
df.shape
# Out:
# (360, 10)

# %%
# Назви всіх стовпців
df.columns
# Out:
# Index(['order_id', 'date', 'city', 'product', 'category', 'unit_price',
#        'quantity', 'discount_pct', 'revenue', 'manager'],
#       dtype='object')

# %%
# Загальна інформація: типи даних, кількість непорожніх значень
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      360 non-null    int64
#  1   date          360 non-null    object
#  2   city          360 non-null    object
#  3   product       360 non-null    object
#  4   category      360 non-null    object
#  5   unit_price    360 non-null    int64
#  6   quantity      360 non-null    int64
#  7   discount_pct  360 non-null    int64
#  8   revenue       360 non-null    float64
#  9   manager       360 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 28.3+ KB

# %%
# Статистика по числових стовпцях: середнє, мін, макс, тощо
df.describe()
# Out:
#           order_id  unit_price    quantity  discount_pct     revenue
# count   360.000000  360.000000  360.000000    360.000000  360.000000
# mean   1180.500000   73.972222    2.136111      1.472222  157.688889
# std     104.067286   25.290497    1.192281      3.794778  109.374416
# min    1001.000000   40.000000    1.000000      0.000000   38.000000
# 25%    1090.750000   55.000000    1.000000      0.000000   70.000000
# 50%    1180.500000   65.000000    2.000000      0.000000  120.000000
# 75%    1270.250000   95.000000    3.000000      0.000000  220.000000
# max    1360.000000  120.000000    5.000000     15.000000  600.000000

# %% [markdown]
# > 💡 `.head(n)` показує перші `n` рядків, `.tail(n)` — останні. Це найперше, що варто робити з будь-яким новим датасетом.

# %%
# Останні 3 рядки
df.tail(3)
# Out:
#      order_id        date   city  product category  unit_price  quantity  \
# 357      1032  2024-01-10  Львів  Сендвіч      Їжа          95         4
# 358      1296  2024-05-04   Київ  Еспресо    Напої          45         4
# 359      1196  2024-04-05  Одеса      Чай    Напої          40         1
#
#      discount_pct  revenue manager
# 357             0    380.0   Олена
# 358             0    180.0   Олена
# 359             5     38.0   Марія

# %% [markdown]
# ## 3. Вибір стовпців
#
# Щоб вибрати один стовпець, використовуємо квадратні дужки з назвою стовпця.

# %%
# Один стовпець (повертає Series - одновимірну колонку)
df["city"]
# Out:
# 0       Львів
# 1      Харків
# 2      Харків
# 3       Львів
# 4       Львів
#         ...
# 355    Харків
# 356      Київ
# 357     Львів
# 358      Київ
# 359     Одеса
# Name: city, Length: 360, dtype: object

# %%
# Кілька стовпців (повертає DataFrame - подвійні дужки!)
df[["product", "revenue"]].head()
# Out:
#     product  revenue
# 0      Лате    140.0
# 1       Чай     76.0
# 2    Маффін     60.0
# 3  Капучіно     65.0
# 4      Лате     63.0

# %% [markdown]
# ### Базові операції зі стовпцем
#
# Зі стовпцем-числом можна одразу рахувати агрегати:

# %%
print("Загальна виручка:", df["revenue"].sum())
print("Середня виручка:", df["revenue"].mean())
print("Максимальна виручка:", df["revenue"].max())
print("Мінімальна виручка:", df["revenue"].min())
print("Кількість замовлень:", df["revenue"].count())
# Out:
# Загальна виручка: 56768.0
# Середня виручка: 157.6888888888889
# Максимальна виручка: 600.0
# Мінімальна виручка: 38.0
# Кількість замовлень: 360

# %%
# Скільки унікальних міст?
df["city"].unique()
# Out:
# array(['Львів', 'Харків', 'Київ', 'Одеса'], dtype=object)

# %%
# Скільки замовлень у кожному місті? value_counts() - дуже корисна команда!
df["city"].value_counts()
# Out:
# city
# Київ      100
# Львів      88
# Одеса      88
# Харків     84
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Фільтрація рядків
#
# Це одна з найважливіших операцій. Ми хочемо вибрати тільки ті рядки, які відповідають умові.
#
# Принцип: всередині `df[...]` ми пишемо умову, яка повертає `True`/`False` для кожного рядка.

# %%
# Тільки замовлення з Києва
kyiv_orders = df[df["city"] == "Київ"]
kyiv_orders.head()
# Out:
#     order_id        date  city   product category  unit_price  quantity  \
# 5       1164  2024-03-20  Київ   Чізкейк  Десерти         110         2
# 6       1338  2024-06-02  Київ  Тірамісу  Десерти         120         3
# 8       1169  2024-03-18  Київ    Маффін  Випічка          60         1
# 9       1193  2024-04-27  Київ      Лате    Напої          70         5
# 11      1170  2024-03-10  Київ   Еспресо    Напої          45         1
#
#     discount_pct  revenue manager
# 5              0    220.0   Марія
# 6              0    360.0  Андрій
# 8              0     60.0  Андрій
# 9              0    350.0   Олена
# 11             0     45.0   Марія

# %%
# Скільки замовлень з Києва?
len(kyiv_orders)
# Out:
# 100

# %%
# Замовлення з виручкою більше 200 грн
big_orders = df[df["revenue"] > 200]
print("Великих замовлень:", len(big_orders))
big_orders.head()
# Out:
# Великих замовлень: 100
#     order_id        date   city   product category  unit_price  quantity  \
# 5       1164  2024-03-20   Київ   Чізкейк  Десерти         110         2
# 6       1338  2024-06-02   Київ  Тірамісу  Десерти         120         3
# 9       1193  2024-04-27   Київ      Лате    Напої          70         5
# 13      1213  2024-04-20  Львів  Капучіно    Напої          65         4
# 16      1059  2024-01-22   Київ    Маффін  Випічка          60         4
#
#     discount_pct  revenue manager
# 5              0    220.0   Марія
# 6              0    360.0  Андрій
# 9              0    350.0   Олена
# 13             0    260.0  Андрій
# 16             0    240.0  Андрій

# %% [markdown]
# ### Кілька умов одночасно
#
# Для поєднання умов використовуємо `&` (І) та `|` (АБО). **Важливо:** кожну умову беремо в дужки!

# %%
# Замовлення з Києва І виручкою більше 150
result = df[(df["city"] == "Київ") & (df["revenue"] > 150)]
result.head()
# Out:
#     order_id        date  city   product category  unit_price  quantity  \
# 5       1164  2024-03-20  Київ   Чізкейк  Десерти         110         2
# 6       1338  2024-06-02  Київ  Тірамісу  Десерти         120         3
# 9       1193  2024-04-27  Київ      Лате    Напої          70         5
# 16      1059  2024-01-22  Київ    Маффін  Випічка          60         4
# 19      1192  2024-04-26  Київ   Сендвіч      Їжа          95         4
#
#     discount_pct  revenue manager
# 5              0    220.0   Марія
# 6              0    360.0  Андрій
# 9              0    350.0   Олена
# 16             0    240.0  Андрій
# 19             0    380.0  Андрій

# %%
# Замовлення з категорії Десерти АБО Випічка
sweets = df[(df["category"] == "Десерти") | (df["category"] == "Випічка")]
print("Солодких замовлень:", len(sweets))
sweets.head()
# Out:
# Солодких замовлень: 146
#    order_id        date    city   product category  unit_price  quantity  \
# 2      1003  2024-01-14  Харків    Маффін  Випічка          60         1
# 5      1164  2024-03-20    Київ   Чізкейк  Десерти         110         2
# 6      1338  2024-06-02    Київ  Тірамісу  Десерти         120         3
# 7      1044  2024-01-01  Харків   Чізкейк  Десерти         110         1
# 8      1169  2024-03-18    Київ    Маффін  Випічка          60         1
#
#    discount_pct  revenue manager
# 2             0     60.0   Олена
# 5             0    220.0   Марія
# 6             0    360.0  Андрій
# 7             0    110.0   Олена
# 8             0     60.0  Андрій

# %% [markdown]
# > 💡 Поширена помилка: писати `and`/`or` замість `&`/`|`. У pandas для фільтрації використовуються саме символи `&` та `|`, і кожна умова має бути в дужках.

# %% [markdown]
# ## 5. Створення нових стовпців
#
# Дуже часто треба порахувати щось нове на основі наявних даних. Новий стовпець створюється просто — присвоюємо значення новій назві.

# %%
# Порахуємо виручку без знижки (повна ціна)
df["full_price"] = df["unit_price"] * df["quantity"]
df[["product", "unit_price", "quantity", "full_price", "revenue"]].head()
# Out:
#     product  unit_price  quantity  full_price  revenue
# 0      Лате          70         2         140    140.0
# 1       Чай          40         2          80     76.0
# 2    Маффін          60         1          60     60.0
# 3  Капучіно          65         1          65     65.0
# 4      Лате          70         1          70     63.0

# %%
# Скільки грн втрачено на знижці?
df["discount_amount"] = df["full_price"] - df["revenue"]
df[["product", "full_price", "discount_pct", "discount_amount"]].head()
# Out:
#     product  full_price  discount_pct  discount_amount
# 0      Лате         140             0              0.0
# 1       Чай          80             5              4.0
# 2    Маффін          60             0              0.0
# 3  Капучіно          65             0              0.0
# 4      Лате          70            10              7.0

# %% [markdown]
# > 💡 Операції застосовуються одразу до ВСЬОГО стовпця — не треба писати цикл! Це називається «векторизація» і це одна з головних переваг pandas.

# %% [markdown]
# ## 6. Сортування
#
# `sort_values()` сортує таблицю за вказаним стовпцем.

# %%
# Топ-5 найбільших замовлень за виручкою
df.sort_values("revenue", ascending=False).head()
# Out:
#      order_id        date    city   product category  unit_price  quantity  \
# 239      1029  2024-01-16    Київ  Тірамісу  Десерти         120         5
# 78       1135  2024-03-27   Львів  Тірамісу  Десерти         120         5
# 23       1248  2024-05-24   Львів   Чізкейк  Десерти         110         5
# 344      1115  2024-02-05  Харків   Чізкейк  Десерти         110         5
# 302      1076  2024-02-01  Харків   Чізкейк  Десерти         110         5
#
#      discount_pct  revenue manager  full_price  discount_amount
# 239             0    600.0   Марія         600              0.0
# 78              0    600.0  Андрій         600              0.0
# 23              0    550.0   Олена         550              0.0
# 344             0    550.0  Андрій         550              0.0
# 302             5    522.5   Олена         550             27.5

# %%
# Найдешевші замовлення (за зростанням)
df.sort_values("revenue", ascending=True).head()
# Out:
#      order_id        date    city product category  unit_price  quantity  \
# 359      1196  2024-04-05   Одеса     Чай    Напої          40         1
# 300      1237  2024-04-09  Харків     Чай    Напої          40         1
# 30       1243  2024-05-27   Одеса     Чай    Напої          40         1
# 28       1017  2024-01-25   Львів     Чай    Напої          40         1
# 339      1160  2024-03-09   Одеса     Чай    Напої          40         1
#
#      discount_pct  revenue manager  full_price  discount_amount
# 359             5     38.0   Марія          40              2.0
# 300             5     38.0  Андрій          40              2.0
# 30              0     40.0  Богдан          40              0.0
# 28              0     40.0   Марія          40              0.0
# 339             0     40.0  Андрій          40              0.0

# %% [markdown]
# ## 7. Групування — `groupby()` 🔥
#
# Це найпотужніший інструмент pandas і серце аналітики даних. Ідея: розбити дані на групи і порахувати щось для кожної групи.
#
# **Аналогія:** це те саме, що Pivot Table в Excel.
#
# Схема: `df.groupby("стовпець")["що_рахувати"].агрегат()`

# %%
# Загальна виручка по кожному місту
df.groupby("city")["revenue"].sum()
# Out:
# city
# Київ      15465.0
# Львів     14726.0
# Одеса     12988.5
# Харків    13588.5
# Name: revenue, dtype: float64

# %%
# Середня виручка по категоріях
df.groupby("category")["revenue"].mean()
# Out:
# category
# Їжа        198.550000
# Випічка    117.700658
# Десерти    253.064286
# Напої      129.379888
# Name: revenue, dtype: float64

# %%
# Кількість замовлень по менеджерах
df.groupby("manager")["order_id"].count()
# Out:
# manager
# Андрій    118
# Богдан     78
# Марія      77
# Олена      87
# Name: order_id, dtype: int64

# %% [markdown]
# ### Сортуємо результат групування
#
# Результат groupby — це теж дані, які можна сортувати. Часто хочемо побачити лідерів.

# %%
# Топ продуктів за загальною виручкою
df.groupby("product")["revenue"].sum().sort_values(ascending=False)
# Out:
# product
# Чізкейк     9740.50
# Тірамісу    7974.00
# Сендвіч     6949.25
# Раф         6719.25
# Лате        5747.00
# Маффін      4845.00
# Капучіно    4751.50
# Круасан     4100.25
# Чай         3176.00
# Еспресо     2765.25
# Name: revenue, dtype: float64

# %% [markdown]
# ### Кілька агрегатів одночасно
#
# Метод `.agg()` дозволяє порахувати кілька показників за один раз.

# %%
# По містах: сума, середнє та кількість замовлень
df.groupby("city")["revenue"].agg(["sum", "mean", "count"])
# Out:
#             sum        mean  count
# city
# Київ    15465.0  154.650000    100
# Львів   14726.0  167.340909     88
# Одеса   12988.5  147.596591     88
# Харків  13588.5  161.767857     84

# %%
# Групування за ДВОМА стовпцями: місто + категорія
df.groupby(["city", "category"])["revenue"].sum()
# Out:
# city    category
# Київ    Їжа         1980.75
#         Випічка     3020.00
#         Десерти     5279.50
#         Напої       5184.75
# Львів   Їжа         1767.00
#         Випічка     2131.00
#         Десерти     4692.00
#         Напої       6136.00
# Одеса   Їжа         1216.00
#         Випічка     2312.50
#         Десерти     3857.00
#         Напої       5603.00
# Харків  Їжа         1985.50
#         Випічка     1481.75
#         Десерти     3886.00
#         Напої       6235.25
# Name: revenue, dtype: float64

# %% [markdown]
# ## 8. Робота з датами
#
# Зараз стовпець `date` — це просто текст. Щоб працювати з ним як з датою (виділяти місяць, рік), треба перетворити його через `pd.to_datetime()`.

# %%
# Перетворюємо текст на дату
df["date"] = pd.to_datetime(df["date"])
df["date"].head()
# Out:
# 0   2024-05-21
# 1   2024-05-25
# 2   2024-01-14
# 3   2024-04-21
# 4   2024-02-16
# Name: date, dtype: datetime64[ns]

# %%
# Тепер можна виділити місяць, рік, день тижня
df["month"] = df["date"].dt.month
df["day_name"] = df["date"].dt.day_name()
df[["date", "month", "day_name"]].head()
# Out:
#         date  month  day_name
# 0 2024-05-21      5   Tuesday
# 1 2024-05-25      5  Saturday
# 2 2024-01-14      1    Sunday
# 3 2024-04-21      4    Sunday
# 4 2024-02-16      2    Friday

# %%
# Виручка по місяцях - класичний часовий аналіз
df.groupby("month")["revenue"].sum()
# Out:
# month
# 1    9624.25
# 2    9632.25
# 3    8540.25
# 4    9571.00
# 5    9808.50
# 6    9591.75
# Name: revenue, dtype: float64

# %% [markdown]
# ## 9. Збираємо все разом: міні-аналіз
#
# Тепер застосуємо все вивчене, щоб відповісти на реальні бізнес-питання про кав'ярні.

# %% [markdown]
# **Питання 1:** Яке місто приносить найбільше грошей?

# %%
revenue_by_city = df.groupby("city")["revenue"].sum().sort_values(ascending=False)
print(revenue_by_city)
print()
print("Лідер:", revenue_by_city.index[0])
# Out:
# city
# Київ      15465.0
# Львів     14726.0
# Харків    13588.5
# Одеса     12988.5
# Name: revenue, dtype: float64
#
# Лідер: Київ

# %% [markdown]
# **Питання 2:** Які 3 продукти найприбутковіші?

# %%
top_products = df.groupby("product")["revenue"].sum().sort_values(ascending=False)
top_products.head(3)
# Out:
# product
# Чізкейк     9740.50
# Тірамісу    7974.00
# Сендвіч     6949.25
# Name: revenue, dtype: float64

# %% [markdown]
# **Питання 3:** Хто з менеджерів продав найбільше?

# %%
df.groupby("manager")["revenue"].sum().sort_values(ascending=False)
# Out:
# manager
# Андрій    19540.5
# Олена     14734.0
# Богдан    11313.5
# Марія     11180.0
# Name: revenue, dtype: float64

# %% [markdown]
# **Питання 4:** Як змінювалась виручка від місяця до місяця?

# %%
monthly = df.groupby("month")["revenue"].sum()
print(monthly)

# Можна навіть швидко побудувати графік прямо в pandas!
monthly.plot(kind="bar", title="Виручка по місяцях")
# Out:
# month
# 1    9624.25
# 2    9632.25
# 3    8540.25
# 4    9571.00
# 5    9808.50
# 6    9591.75
# Name: revenue, dtype: float64
# <Axes: title={'center': 'Виручка по місяцях'}, xlabel='month'>

# %% [markdown]
# > 💡 pandas вміє будувати швидкі графіки через `.plot()`. Для серйозної візуалізації використовують matplotlib чи seaborn, але для швидкого погляду `.plot()` ідеальний.

# %% [markdown]
# ---
#
# # 🎯 Завдання для практики
#
# Тепер ваша черга! Спробуйте розв'язати ці завдання самостійно. Дані вже завантажені у `df`.
#
# Якщо щось не виходить — поверніться до прикладів вище, вони містять усе необхідне.

# %% [markdown]
# ### Завдання 1 ⭐
# Виведіть перші 10 рядків таблиці.

# %%
# Ваш код:
df.head(10)
# Out:
#    order_id       date    city   product category  unit_price  quantity  \
# 0      1255 2024-05-21   Львів      Лате    Напої          70         2
# 1      1299 2024-05-25  Харків       Чай    Напої          40         2
# 2      1003 2024-01-14  Харків    Маффін  Випічка          60         1
# 3      1226 2024-04-21   Львів  Капучіно    Напої          65         1
# 4      1114 2024-02-16   Львів      Лате    Напої          70         1
# 5      1164 2024-03-20    Київ   Чізкейк  Десерти         110         2
# 6      1338 2024-06-02    Київ  Тірамісу  Десерти         120         3
# 7      1044 2024-01-01  Харків   Чізкейк  Десерти         110         1
# 8      1169 2024-03-18    Київ    Маффін  Випічка          60         1
# 9      1193 2024-04-27    Київ      Лате    Напої          70         5
#
#    discount_pct  revenue manager  full_price  discount_amount  month  \
# 0             0    140.0   Олена         140              0.0      5
# 1             5     76.0  Богдан          80              4.0      5
# 2             0     60.0   Олена          60              0.0      1
# 3             0     65.0   Олена          65              0.0      4
# 4            10     63.0  Андрій          70              7.0      2
# 5             0    220.0   Марія         220              0.0      3
# 6             0    360.0  Андрій         360              0.0      6
# 7             0    110.0   Олена         110              0.0      1
# 8             0     60.0  Андрій          60              0.0      3
# 9             0    350.0   Олена         350              0.0      4
#
#     day_name
# 0    Tuesday
# 1   Saturday
# 2     Sunday
# 3     Sunday
# 4     Friday
# 5  Wednesday
# 6     Sunday
# 7     Monday
# 8     Monday
# 9   Saturday

# %% [markdown]
# ### Завдання 2 ⭐
# Знайдіть, скільки всього унікальних продуктів у даних.
#
# Підказка: метод `.nunique()` рахує кількість унікальних значень.

# %%
# Ваш код:
df.nunique()
# Out:
# order_id           360
# date               147
# city                 4
# product             10
# category             4
# unit_price          10
# quantity             5
# discount_pct         4
# revenue             83
# manager              4
# full_price          44
# discount_amount     36
# month                6
# day_name             7
# dtype: int64

# %% [markdown]
# ### Завдання 3 ⭐
# Виведіть усі замовлення з міста Львів.

# %%
# Ваш код:
df[df['city']=='Львів']
# Out:
#      order_id       date   city   product category  unit_price  quantity  \
# 0        1255 2024-05-21  Львів      Лате    Напої          70         2
# 3        1226 2024-04-21  Львів  Капучіно    Напої          65         1
# 4        1114 2024-02-16  Львів      Лате    Напої          70         1
# 13       1213 2024-04-20  Львів  Капучіно    Напої          65         4
# 14       1262 2024-05-24  Львів    Маффін  Випічка          60         2
# ..        ...        ...    ...       ...      ...         ...       ...
# 332      1134 2024-03-17  Львів  Капучіно    Напої          65         3
# 335      1010 2024-01-11  Львів      Лате    Напої          70         2
# 338      1129 2024-03-15  Львів       Чай    Напої          40         1
# 345      1046 2024-01-08  Львів  Капучіно    Напої          65         1
# 357      1032 2024-01-10  Львів   Сендвіч      Їжа          95         4
#
#      discount_pct  revenue manager  full_price  discount_amount  month  \
# 0               0    140.0   Олена         140              0.0      5
# 3               0     65.0   Олена          65              0.0      4
# 4              10     63.0  Андрій          70              7.0      2
# 13              0    260.0  Андрій         260              0.0      4
# 14             10    108.0   Марія         120             12.0      5
# ..            ...      ...     ...         ...              ...    ...
# 332             0    195.0   Олена         195              0.0      3
# 335             0    140.0  Богдан         140              0.0      1
# 338             0     40.0   Марія          40              0.0      3
# 345             0     65.0   Марія          65              0.0      1
# 357             0    380.0   Олена         380              0.0      1
#
#       day_name
# 0      Tuesday
# 3       Sunday
# 4       Friday
# 13    Saturday
# 14      Friday
# ..         ...
# 332     Sunday
# 335   Thursday
# 338     Friday
# 345     Monday
# 357  Wednesday
#
# [88 rows x 14 columns]

# %% [markdown]
# ### Завдання 4 ⭐⭐
# Знайдіть усі замовлення, де була застосована знижка (discount_pct більше 0).
# Скільки таких замовлень?
# ___
# 56 замовлень

# %%
# Ваш код:
display(df[df['discount_pct']>0])
len(df[df['discount_pct']>0])
# Out:
#      order_id       date    city   product category  unit_price  quantity  \
# 1        1299 2024-05-25  Харків       Чай    Напої          40         2
# 4        1114 2024-02-16   Львів      Лате    Напої          70         1
# 14       1262 2024-05-24   Львів    Маффін  Випічка          60         2
# 20       1119 2024-02-05    Київ  Тірамісу  Десерти         120         1
# 25       1218 2024-04-28    Київ   Чізкейк  Десерти         110         4
# 26       1054 2024-01-17   Одеса  Тірамісу  Десерти         120         2
# 34       1104 2024-02-04    Київ   Чізкейк  Десерти         110         3
# 39       1005 2024-01-10    Київ       Раф    Напої          85         1
# 46       1147 2024-03-09    Київ  Тірамісу  Десерти         120         1
# 52       1316 2024-06-12   Одеса   Сендвіч      Їжа          95         2
# 68       1328 2024-06-13   Одеса  Капучіно    Напої          65         1
# 75       1344 2024-06-11   Львів  Капучіно    Напої          65         1
# 77       1067 2024-02-03   Одеса  Капучіно    Напої          65         2
# 87       1279 2024-05-16    Київ   Круасан  Випічка          55         2
# 92       1223 2024-04-14  Харків   Сендвіч      Їжа          95         2
# 94       1339 2024-06-24   Львів      Лате    Напої          70         4
# 98       1075 2024-02-23   Львів       Раф    Напої          85         1
# 119      1291 2024-05-03   Одеса   Круасан  Випічка          55         1
# 124      1346 2024-06-22   Львів   Сендвіч      Їжа          95         1
# 128      1281 2024-05-01  Харків   Еспресо    Напої          45         2
# 130      1240 2024-04-24   Одеса   Чізкейк  Десерти         110         1
# 133      1039 2024-01-27   Львів  Тірамісу  Десерти         120         2
# 140      1106 2024-02-09   Одеса    Маффін  Випічка          60         3
# 143      1122 2024-03-16    Київ    Маффін  Випічка          60         3
# 144      1025 2024-01-15  Харків  Капучіно    Напої          65         1
# 154      1246 2024-05-20   Одеса   Круасан  Випічка          55         3
# 155      1283 2024-05-03   Одеса    Маффін  Випічка          60         2
# 157      1162 2024-03-02  Харків       Раф    Напої          85         3
# 168      1015 2024-01-27    Київ   Круасан  Випічка          55         2
# 180      1245 2024-05-08   Львів   Чізкейк  Десерти         110         2
# 192      1121 2024-03-01  Харків   Круасан  Випічка          55         3
# 196      1201 2024-04-19  Харків   Чізкейк  Десерти         110         1
# 202      1099 2024-02-07   Одеса    Маффін  Випічка          60         1
# 209      1277 2024-05-07    Київ   Сендвіч      Їжа          95         3
# 212      1023 2024-01-23   Одеса       Чай    Напої          40         2
# 229      1349 2024-06-05   Львів  Капучіно    Напої          65         3
# 234      1031 2024-01-17   Львів   Сендвіч      Їжа          95         1
# 243      1112 2024-02-09   Одеса   Круасан  Випічка          55         3
# 245      1333 2024-06-02   Львів  Капучіно    Напої          65         4
# 246      1358 2024-06-02   Львів   Еспресо    Напої          45         2
# 254      1161 2024-03-04   Львів      Лате    Напої          70         2
# 257      1018 2024-01-16   Львів       Раф    Напої          85         1
# 259      1320 2024-06-27   Львів    Маффін  Випічка          60         2
# 261      1315 2024-06-19   Одеса   Еспресо    Напої          45         3
# 272      1351 2024-06-07   Львів   Чізкейк  Десерти         110         2
# 278      1181 2024-04-27   Львів       Чай    Напої          40         2
# 286      1172 2024-03-12  Харків  Капучіно    Напої          65         4
# 289      1174 2024-03-15    Київ      Лате    Напої          70         2
# 300      1237 2024-04-09  Харків       Чай    Напої          40         1
# 302      1076 2024-02-01  Харків   Чізкейк  Десерти         110         5
# 306      1278 2024-05-22   Львів   Сендвіч      Їжа          95         1
# 309      1311 2024-06-23   Одеса   Круасан  Випічка          55         1
# 320      1092 2024-02-16   Львів       Раф    Напої          85         3
# 321      1049 2024-01-25   Львів   Сендвіч      Їжа          95         2
# 325      1123 2024-03-27    Київ      Лате    Напої          70         1
# 359      1196 2024-04-05   Одеса       Чай    Напої          40         1
#
#      discount_pct  revenue manager  full_price  discount_amount  month  \
# 1               5    76.00  Богдан          80             4.00      5
# 4              10    63.00  Андрій          70             7.00      2
# 14             10   108.00   Марія         120            12.00      5
# 20             15   102.00  Андрій         120            18.00      2
# 25             10   396.00   Марія         440            44.00      4
# 26              5   228.00  Андрій         240            12.00      1
# 34              5   313.50  Андрій         330            16.50      2
# 39              5    80.75  Богдан          85             4.25      1
# 46             10   108.00  Андрій         120            12.00      3
# 52             10   171.00   Олена         190            19.00      6
# 68             15    55.25   Олена          65             9.75      6
# 75              5    61.75  Андрій          65             3.25      6
# 77              5   123.50  Андрій         130             6.50      2
# 87              5   104.50  Богдан         110             5.50      5
# 92              5   180.50  Андрій         190             9.50      4
# 94              5   266.00  Андрій         280            14.00      6
# 98              5    80.75  Андрій          85             4.25      2
# 119            15    46.75   Олена          55             8.25      5
# 124            10    85.50  Андрій          95             9.50      6
# 128             5    85.50  Андрій          90             4.50      5
# 130            10    99.00   Олена         110            11.00      4
# 133            10   216.00   Олена         240            24.00      1
# 140             5   171.00   Олена         180             9.00      2
# 143            10   162.00  Богдан         180            18.00      3
# 144            15    55.25  Андрій          65             9.75      1
# 154             5   156.75  Андрій         165             8.25      5
# 155            15   102.00  Андрій         120            18.00      5
# 157            10   229.50   Марія         255            25.50      3
# 168            15    93.50  Богдан         110            16.50      1
# 180            10   198.00  Андрій         220            22.00      5
# 192             5   156.75  Андрій         165             8.25      3
# 196            15    93.50  Андрій         110            16.50      4
# 202            10    54.00   Олена          60             6.00      2
# 209             5   270.75  Богдан         285            14.25      5
# 212            15    68.00   Олена          80            12.00      1
# 229            15   165.75   Олена         195            29.25      6
# 234            15    80.75   Марія          95            14.25      1
# 243            15   140.25  Богдан         165            24.75      2
# 245            10   234.00   Олена         260            26.00      6
# 246            15    76.50  Андрій          90            13.50      6
# 254            15   119.00   Олена         140            21.00      3
# 257            10    76.50   Олена          85             8.50      1
# 259            10   108.00   Марія         120            12.00      6
# 261             5   128.25  Андрій         135             6.75      6
# 272            10   198.00   Марія         220            22.00      6
# 278             5    76.00  Богдан          80             4.00      4
# 286            15   221.00  Андрій         260            39.00      3
# 289            10   126.00  Андрій         140            14.00      3
# 300             5    38.00  Андрій          40             2.00      4
# 302             5   522.50   Олена         550            27.50      2
# 306             5    90.25   Олена          95             4.75      5
# 309            15    46.75   Марія          55             8.25      6
# 320            15   216.75  Богдан         255            38.25      2
# 321             5   180.50  Андрій         190             9.50      1
# 325            10    63.00  Богдан          70             7.00      3
# 359             5    38.00   Марія          40             2.00      4
#
#       day_name
# 1     Saturday
# 4       Friday
# 14      Friday
# 20      Monday
# 25      Sunday
# 26   Wednesday
# 34      Sunday
# 39   Wednesday
# 46    Saturday
# 52   Wednesday
# 68    Thursday
# 75     Tuesday
# 77    Saturday
# 87    Thursday
# 92      Sunday
# 94      Monday
# 98      Friday
# 119     Friday
# 124   Saturday
# 128  Wednesday
# 130  Wednesday
# 133   Saturday
# 140     Friday
# 143   Saturday
# 144     Monday
# 154     Monday
# 155     Friday
# 157   Saturday
# 168   Saturday
# 180  Wednesday
# 192     Friday
# 196     Friday
# 202  Wednesday
# 209    Tuesday
# 212    Tuesday
# 229  Wednesday
# 234  Wednesday
# 243     Friday
# 245     Sunday
# 246     Sunday
# 254     Monday
# 257    Tuesday
# 259   Thursday
# 261  Wednesday
# 272     Friday
# 278   Saturday
# 286    Tuesday
# 289     Friday
# 300    Tuesday
# 302   Thursday
# 306  Wednesday
# 309     Sunday
# 320     Friday
# 321   Thursday
# 325  Wednesday
# 359     Friday
# 56

# %% [markdown]
# ### Завдання 5 ⭐⭐
# Створіть новий стовпець `is_big`, який дорівнює `True`, якщо виручка більша за 150, і `False` інакше.
#
# Підказка: `df["is_big"] = df["revenue"] > 150`

# %%
# Ваш код:
df['is_big'] = df['revenue']>150

# %% [markdown]
# ### Завдання 6 ⭐⭐
# Порахуйте загальну виручку по кожній категорії товарів (Напої, Випічка, Десерти, Їжа).
# Відсортуйте за спаданням.

# %%
# Ваш код:
df.groupby('category')['revenue'].sum().sort_values(ascending=False)
# Out:
# category
# Напої      23159.00
# Десерти    17714.50
# Випічка     8945.25
# Їжа         6949.25
# Name: revenue, dtype: float64

# %% [markdown]
# ### Завдання 7 ⭐⭐
# Яка середня кількість товарів (quantity) у одному замовленні в кожному місті?

# %%
# Ваш код:
df.groupby('city')['quantity'].mean().round(2)
# Out:
# city
# Київ      2.09
# Львів     2.27
# Одеса     2.06
# Харків    2.13
# Name: quantity, dtype: float64

# %% [markdown]
# ### Завдання 8 ⭐⭐⭐
# Знайдіть найприбутковіший продукт у КОЖНОМУ місті.
#
# Підказка: згрупуйте за двома стовпцями `["city", "product"]`, порахуйте суму виручки, а потім подумайте, як знайти максимум у кожному місті (можна подивитись на `.idxmax()` або відсортувати).

# %%
# Ваш код:m
grouped = df.groupby(['city', 'product'])['revenue'].sum().sort_values(ascending=False)
best_value_city = grouped.groupby(level='city').max()
best_per_city = grouped.groupby(level='city').idxmax()
print(best_per_city, best_value_city)
# Out:
# city
# Київ        (Київ, Чізкейк)
# Львів     (Львів, Тірамісу)
# Одеса      (Одеса, Чізкейк)
# Харків    (Харків, Чізкейк)
# Name: revenue, dtype: object city
# Київ      2909.5
# Львів     2976.0
# Одеса     2189.0
# Харків    2926.0
# Name: revenue, dtype: float64

# %% [markdown]
# ### Завдання 9 ⭐⭐⭐
# Порахуйте, який відсоток від загальної виручки компанії припадає на кожне місто.
#
# Підказка: спочатку порахуйте виручку по містах, потім поділіть на загальну суму і помножте на 100.

# %%
# Ваш код:
city_revenue = df.groupby('city')['revenue'].sum()
pct = city_revenue / df['revenue'].sum() * 100

pct.round(2)
# Out:
# city
# Київ      27.24
# Львів     25.94
# Одеса     22.88
# Харків    23.94
# Name: revenue, dtype: float64

# %% [markdown]
# ### Завдання 10 ⭐⭐⭐
# У який день тижня кав'ярні заробляють найбільше?
#
# Підказка: вам знадобиться стовпець `day_name`, який ми створили раніше. Згрупуйте за ним.

# %%
# Ваш код:
df.groupby('day_name')['revenue'].sum()
# Out:
# day_name
# Friday       10030.75
# Monday        7519.00
# Saturday      9995.00
# Sunday        8262.25
# Thursday      6510.75
# Tuesday       7266.00
# Wednesday     7184.25
# Name: revenue, dtype: float64

# %% [markdown]
# ---
#
# # 🎉 Чудово!
#
# Сьогодні ви познайомились з основами pandas:
#
# - ✅ Завантаження даних з CSV (`read_csv`)
# - ✅ Перший погляд на дані (`head`, `info`, `describe`, `shape`)
# - ✅ Вибір стовпців
# - ✅ Фільтрація рядків за умовами
# - ✅ Створення нових стовпців
# - ✅ Сортування (`sort_values`)
# - ✅ Групування (`groupby`) — найважливіше!
# - ✅ Робота з датами
# - ✅ Швидкі графіки (`.plot()`)
#
# ### Що далі?
# - Метод `merge()` — об'єднання кількох таблиць (як JOIN у SQL)
# - Pivot-таблиці (`pivot_table`)
# - Обробка пропущених значень (`fillna`, `dropna`)
# - Серйозна візуалізація з matplotlib та seaborn
#
# **pandas — це фундамент аналітики даних у Python. Практикуйтесь! 🐼**
