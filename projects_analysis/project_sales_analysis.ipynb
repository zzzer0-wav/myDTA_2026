# %% [markdown]
# <a href="https://colab.research.google.com/github/zzzer0-wav/myDTA_2026/blob/main/projects_analysis/project_sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Аналіз продажів магазину

# %% [markdown]
# Вхідний датасет (дані)
# ---

# %%
# Запусти цей блок, щоб отримати датасет
import pandas as pd
import numpy as np

np.random.seed(42)
n = 300

categories = ['Молочне', 'Хліб та випічка', 'М\'ясо та риба', 'Овочі та фрукти', 'Напої']
products = {
    'Молочне':          ['Молоко 1л', 'Кефір 0.5л', 'Сир кисломолочний', 'Масло вершкове', 'Йогурт'],
    'Хліб та випічка':  ['Хліб білий', 'Батон', 'Булочка', 'Хліб житній', 'Круасан'],
    'М\'ясо та риба':   ['Куряче філе', 'Свинина', 'Ковбаса', 'Риба хек', 'Сосиски'],
    'Овочі та фрукти':  ['Картопля', 'Морква', 'Яблука', 'Банани', 'Помідори'],
    'Напої':            ['Вода 1.5л', 'Сік апельсиновий', 'Чай', 'Кава мелена', 'Лимонад'],
}
prices = {
    'Молоко 1л': 38, 'Кефір 0.5л': 22, 'Сир кисломолочний': 55, 'Масло вершкове': 95, 'Йогурт': 30,
    'Хліб білий': 28, 'Батон': 25, 'Булочка': 12, 'Хліб житній': 32, 'Круасан': 18,
    'Куряче філе': 165, 'Свинина': 210, 'Ковбаса': 145, 'Риба хек': 120, 'Сосиски': 98,
    'Картопля': 20, 'Морква': 15, 'Яблука': 45, 'Банани': 52, 'Помідори': 60,
    'Вода 1.5л': 18, 'Сік апельсиновий': 68, 'Чай': 85, 'Кава мелена': 155, 'Лимонад': 35,
}

chosen_cats = np.random.choice(categories, n, p=[0.25, 0.20, 0.20, 0.20, 0.15])
chosen_products = [np.random.choice(products[c]) for c in chosen_cats]

df_origin = pd.DataFrame({
    'transaction_id': range(1001, 1001 + n),
    'date':           pd.to_datetime(
                          np.random.choice(pd.date_range('2024-03-01', '2024-03-31'), n)
                      ),
    'hour':           np.random.choice(range(8, 21), n, p=[0.04,0.06,0.08,0.10,0.12,0.12,0.11,0.10,0.09,0.08,0.06,0.04,0.00]),
    'category':       chosen_cats,
    'product':        chosen_products,
    'quantity':       np.random.randint(1, 6, n),
    'price_uah':      [prices[p] for p in chosen_products],
    'customer_age':   np.random.randint(18, 70, n),
    'payment':        np.random.choice(['Готівка', 'Картка', 'Телефон'], n, p=[0.35, 0.50, 0.15]),
})

# %%
df = df_origin.copy()

# %% [markdown]
# ### Блок 1 - Перше знайомство з даними
# ---

# %%
# Виведи перші 7 рядків датафрейму.

df.head(7)
# Out:
#    transaction_id       date  hour         category         product  quantity  \
# 0            1001 2024-03-17    17  Хліб та випічка         Круасан         4
# 1            1002 2024-03-13    14            Напої     Кава мелена         3
# 2            1003 2024-03-01    18  Овочі та фрукти          Яблука         1
# 3            1004 2024-03-02     8    М'ясо та риба        Риба хек         3
# 4            1005 2024-03-09    19          Молочне          Йогурт         5
# 5            1006 2024-03-03    13          Молочне      Кефір 0.5л         3
# 6            1007 2024-03-31    15          Молочне  Масло вершкове         2
#
#    price_uah  customer_age  payment
# 0         18            28  Готівка
# 1        155            40   Картка
# 2         45            43   Картка
# 3        120            51  Готівка
# 4         30            63   Картка
# 5         22            51   Картка
# 6         95            46  Телефон

# %%
# Дізнайся розмір таблиці (рядки × стовпці).
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  300 non-null    int64
#  1   date            300 non-null    datetime64[ns]
#  2   hour            300 non-null    int64
#  3   category        300 non-null    object
#  4   product         300 non-null    object
#  5   quantity        300 non-null    int64
#  6   price_uah       300 non-null    int64
#  7   customer_age    300 non-null    int64
#  8   payment         300 non-null    object
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 21.2+ KB

# %%
df['total_uah'] = df['price_uah'] * df['quantity']

# %%
()# Виведи типи даних кожного стовпця.
df.dtypes
# Out:
# transaction_id             int64
# date              datetime64[ns]
# hour                       int64
# category                  object
# product                   object
# quantity                   int64
# price_uah                  int64
# customer_age               int64
# payment                   object
# total_uah                  int64
# dtype: object

# %%
print('Типи даних: ')
display(df.dtypes)
# Out:
# Типи даних:
# transaction_id             int64
# date              datetime64[ns]
# hour                       int64
# category                  object
# product                   object
# quantity                   int64
# price_uah                  int64
# customer_age               int64
# payment                   object
# total_uah                  int64
# dtype: object

# %%
df.shape[0]
# Out:
# 300

# %%
print(f'Розмір: {df.shape[0]} рядків, {df.shape[1]} стовбців')
# Out:
# Розмір: 300 рядків, 10 стовбців

# %%
# Перевір, чи є пропущені значення.
print(f'Пропущені значення по стовпцям: \n\n{df.isnull().sum()}')
# Out:
# Пропущені значення по стовпцям:
#
# transaction_id    0
# date              0
# hour              0
# category          0
# product           0
# quantity          0
# price_uah         0
# customer_age      0
# payment           0
# total_uah         0
# dtype: int64

# %%
# Виведи основну статистику (describe) для числових стовпців.
print('Статистика: \n')
df.describe().round(2)
# Out:
# Статистика:
#        transaction_id                 date    hour  quantity  price_uah  \
# count          300.00                  300  300.00    300.00     300.00
# mean          1150.50  2024-03-16 02:14:24   13.72      2.97      63.45
# min           1001.00  2024-03-01 00:00:00    8.00      1.00      12.00
# 25%           1075.75  2024-03-08 00:00:00   12.00      2.00      22.00
# 50%           1150.50  2024-03-16 12:00:00   14.00      3.00      38.00
# 75%           1225.25  2024-03-24 00:00:00   16.00      4.00      95.75
# max           1300.00  2024-03-31 00:00:00   19.00      5.00     210.00
# std             86.75                  NaN    2.74      1.44      51.68
#
#        customer_age  total_uah
# count         300.0     300.00
# mean           43.0     186.97
# min            18.0      12.00
# 25%            31.0      60.00
# 50%            42.5     120.00
# 75%            55.0     256.25
# max            69.0     840.00
# std            14.6     180.27

# %%
# Питання: Яка середня сума однієї покупки? Чи є підозрілі мінімуми/максимуми?

# %% [markdown]
# **ВИСНОВОК**:
#
# Датасет містить информацію про 300 транзакцій, 10 стовпців, пропущених значень немає.
# Середня суцма чеку - 186,87 грн.
# Мінімальний чек - 12.00 ().
# Максимальний чек - 840.00 грн ().
# Підозрілих даних не виявлено.

# %% [markdown]
# ---
# ### Блок 2 - Фільтрація та відбір
# ---

# %%
# Відбери всі покупки категорії «М'ясо та риба».
df[df['category']=="М'ясо та риба"].head()
# Out:
#     transaction_id       date  hour       category      product  quantity  \
# 3             1004 2024-03-02     8  М'ясо та риба     Риба хек         3
# 8             1009 2024-03-21    15  М'ясо та риба      Ковбаса         2
# 17            1018 2024-03-06    14  М'ясо та риба  Куряче філе         3
# 20            1021 2024-03-23     9  М'ясо та риба  Куряче філе         3
# 24            1025 2024-03-10    14  М'ясо та риба      Свинина         4
#
#     price_uah  customer_age  payment  total_uah
# 3         120            51  Готівка        360
# 8         145            34   Картка        290
# 17        165            69   Картка        495
# 20        165            64  Телефон        495
# 24        210            28   Картка        840

# %%
meat_fish = df[df['category']=="М'ясо та риба"]
print(f'У категорії "М\'ясо та риба" {len(meat_fish)} транзакцій')
# Out:
# У категорії "М'ясо та риба" 61 транзакцій

# %%
# Знайди транзакції, де сума (total_uah) перевищує 500 грн.
big = df[df['total_uah']>500]
print(f'Покупки > 500 грн: {len(big)}')
print(big[['product', 'quantity', 'total_uah']].head())
display(big[['product', 'quantity', 'total_uah']].head())
# Out:
# Покупки > 500 грн: 17
#         product  quantity  total_uah
# 24      Свинина         4        840
# 28  Куряче філе         4        660
# 81      Ковбаса         4        580
# 89     Риба хек         5        600
# 93      Свинина         3        630
#         product  quantity  total_uah
# 24      Свинина         4        840
# 28  Куряче філе         4        660
# 81      Ковбаса         4        580
# 89     Риба хек         5        600
# 93      Свинина         3        630

# %% [markdown]
# Відсоток великих покупок

# %%
pct_big = len(big) / len(df) * 100
# round(pct_big, 1)
print(f"Частка покупок > 500: {pct_big:.1f}%")
# Out:
# Частка покупок > 500: 5.7%

# %%
for cat in big.category.unique():
    print(f'{cat} - {big[big['category'] == cat].count()}')
    # print(f'{cat}')
# Out:
# М'ясо та риба - transaction_id    14
# date              14
# hour              14
# category          14
# product           14
# quantity          14
# price_uah         14
# customer_age      14
# payment           14
# total_uah         14
# dtype: int64
# Напої - transaction_id    3
# date              3
# hour              3
# category          3
# product           3
# quantity          3
# price_uah         3
# customer_age      3
# payment           3
# total_uah         3
# dtype: int64

# %% [markdown]
# Відбери покупки, зроблені карткою (payment == 'Картка'), кількістю більше 2 одиниць.

# %%
card_mult = df[(df['payment']=='Картка') & (df['quantity'] > 2)]

print('Картка + кількість > 2:', len(card_mult), '\n')

card_mult.head()
# Out:
# Картка + кількість > 2: 92
#     transaction_id       date  hour       category            product  \
# 1             1002 2024-03-13    14          Напої        Кава мелена
# 4             1005 2024-03-09    19        Молочне             Йогурт
# 5             1006 2024-03-03    13        Молочне         Кефір 0.5л
# 10            1011 2024-03-23    13        Молочне  Сир кисломолочний
# 17            1018 2024-03-06    14  М'ясо та риба        Куряче філе
#
#     quantity  price_uah  customer_age payment  total_uah
# 1          3        155            40  Картка        465
# 4          5         30            63  Картка        150
# 5          3         22            51  Картка         66
# 10         5         55            30  Картка        275
# 17         3        165            69  Картка        495

# %% [markdown]
# Знайди всі покупки покупців молодше 25 років.

# %%
young = df[df['customer_age'] < 25]
print('Покупців до 25: ', len(young), '\n')
young.head
# Out:
# Покупців до 25:  36
# <bound method NDFrame.head of      transaction_id       date  hour         category            product  \
# 7              1008 2024-03-01    17            Напої   Сік апельсиновий
# 19             1020 2024-03-21    16  Хліб та випічка            Круасан
# 26             1027 2024-03-19    13          Молочне             Йогурт
# 36             1037 2024-03-04    14  Хліб та випічка            Круасан
# 38             1039 2024-03-01    10  Овочі та фрукти           Помідори
# 39             1040 2024-03-17    17  Хліб та випічка        Хліб житній
# 40             1041 2024-03-08    16          Молочне             Йогурт
# 65             1066 2024-03-31    14    М'ясо та риба            Свинина
# 66             1067 2024-03-15    13          Молочне          Молоко 1л
# 70             1071 2024-03-21    14  Овочі та фрукти             Банани
# 77             1078 2024-03-28    15          Молочне  Сир кисломолочний
# 86             1087 2024-03-19    16  Овочі та фрукти             Банани
# 129            1130 2024-03-31    10    М'ясо та риба            Сосиски
# 141            1142 2024-03-27    12  Хліб та випічка        Хліб житній
# 154            1155 2024-03-22     8            Напої                Чай
# 155            1156 2024-03-21    18          Молочне     Масло вершкове
# 157            1158 2024-03-01    14  Овочі та фрукти             Банани
# 171            1172 2024-03-25    11          Молочне  Сир кисломолочний
# 175            1176 2024-03-15    13          Молочне          Молоко 1л
# 176            1177 2024-03-24    16  Овочі та фрукти             Морква
# 179            1180 2024-03-31    14          Молочне          Молоко 1л
# 202            1203 2024-03-02    14          Молочне             Йогурт
# 209            1210 2024-03-07    17          Молочне             Йогурт
# 217            1218 2024-03-13    18  Овочі та фрукти           Картопля
# 226            1227 2024-03-05    17            Напої          Вода 1.5л
# 239            1240 2024-03-13    17          Молочне  Сир кисломолочний
# 243            1244 2024-03-10    10  Хліб та випічка              Батон
# 249            1250 2024-03-04    13            Напої          Вода 1.5л
# 267            1268 2024-03-24    15  Овочі та фрукти             Банани
# 269            1270 2024-03-13    10  Хліб та випічка         Хліб білий
# 278            1279 2024-03-06    13  Овочі та фрукти             Яблука
# 280            1281 2024-03-16    13            Напої   Сік апельсиновий
# 284            1285 2024-03-30     9    М'ясо та риба            Свинина
# 287            1288 2024-03-31    17    М'ясо та риба            Ковбаса
# 288            1289 2024-03-24    13  Хліб та випічка            Круасан
# 298            1299 2024-03-24    14    М'ясо та риба            Ковбаса
#
#      quantity  price_uah  customer_age  payment  total_uah
# 7           1         68            21  Готівка         68
# 19          1         18            19  Готівка         18
# 26          3         30            20  Готівка         90
# 36          1         18            23  Телефон         18
# 38          1         60            22  Готівка         60
# 39          1         32            20   Картка         32
# 40          4         30            18  Готівка        120
# 65          2        210            24   Картка        420
# 66          4         38            20  Телефон        152
# 70          2         52            20  Готівка        104
# 77          3         55            24  Готівка        165
# 86          5         52            19  Готівка        260
# 129         4         98            19   Картка        392
# 141         1         32            19  Телефон         32
# 154         2         85            20   Картка        170
# 155         1         95            23   Картка         95
# 157         2         52            23  Готівка        104
# 171         2         55            24   Картка        110
# 175         3         38            21   Картка        114
# 176         5         15            23  Готівка         75
# 179         1         38            20  Готівка         38
# 202         3         30            23  Готівка         90
# 209         4         30            20   Картка        120
# 217         2         20            24  Готівка         40
# 226         1         18            21  Телефон         18
# 239         5         55            19  Готівка        275
# 243         1         25            23  Готівка         25
# 249         2         18            20   Картка         36
# 267         1         52            19  Телефон         52
# 269         4         28            22  Готівка        112
# 278         3         45            19   Картка        135
# 280         4         68            23   Картка        272
# 284         2        210            19  Готівка        420
# 287         2        145            22  Готівка        290
# 288         5         18            18  Телефон         90
# 298         1        145            20  Готівка        145  >

# %% [markdown]
# Скільки унікальних товарів є в датасеті?

# %%
n_unique = df['product'].nunique()
# n_unique

pr_unique = df['product'].unique()
# pr_unique

print('Кількість унікальних товарів:', n_unique, '\n')
print('Перелік унікальних товарів: \n', pr_unique)
# Out:
# Кількість унікальних товарів: 25
#
# Перелік унікальних товарів:
#  [np.str_('Круасан') np.str_('Кава мелена') np.str_('Яблука')
#  np.str_('Риба хек') np.str_('Йогурт') np.str_('Кефір 0.5л')
#  np.str_('Масло вершкове') np.str_('Сік апельсиновий') np.str_('Ковбаса')
#  np.str_('Картопля') np.str_('Сир кисломолочний') np.str_('Морква')
#  np.str_('Куряче філе') np.str_('Хліб житній') np.str_('Батон')
#  np.str_('Хліб білий') np.str_('Свинина') np.str_('Сосиски')
#  np.str_('Молоко 1л') np.str_('Помідори') np.str_('Лимонад')
#  np.str_('Булочка') np.str_('Банани') np.str_('Вода 1.5л') np.str_('Чай')]

# %% [markdown]
# **ВИСНОВОК**
#
# Близько третини покупок оплачено карткою з яких третина - більше 2х товарів у чекові.
#
# 5.7% транзакцій перевищують чек у розмірі 500 грн, здебільшого здійсненні у категорії "М'ясо та риба"
#
# Більше 10% людей (покупців) - молодшого віку (до 25 років)

# %% [markdown]
# ### Блок 3 - Групування та агрегація

# %% [markdown]
# 1. Підрахуй загальний виторг по кожній категорії. Відсортуй за спаданням.

# %%
# revenue_by_cat =
df.groupby('category')['total_uah'].sum().sort_values(ascending=False)
# Out:
# category
# М'ясо та риба      25223
# Напої              10389
# Молочне            10075
# Овочі та фрукти     6270
# Хліб та випічка     4134
# Name: total_uah, dtype: int64

# %% [markdown]
# 2. Знайди топ-5 товарів за кількістю проданих одиниць (сума quantity).

# %%
print(f'топ 5 продуктів за кількістю проданих одиниць')
# top_products =
df.groupby('product')['quantity'].sum().sort_values(ascending=False).head(5)
# Out:
# топ 5 продуктів за кількістю проданих одиниць
# product
# Кефір 0.5л           63
# Сосиски              61
# Йогурт               57
# Сир кисломолочний    54
# Риба хек             48
# Name: quantity, dtype: int64

# %% [markdown]
# 3. Порівняй середню суму покупки для різних способів оплати.

# %%
print('Середній чек по оплаті:\n')
df.groupby('payment')['total_uah'].mean().round(2)
# Out:
# Середній чек по оплаті:
# payment
# Готівка    175.16
# Картка     205.26
# Телефон    144.82
# Name: total_uah, dtype: float64

# %% [markdown]
# 4. Згрупуй по hour - знайди, в які години відбувається найбільше транзакцій.

# %%
df.groupby('hour').size()
# Out:
# hour
# 8      7
# 9     11
# 10    23
# 11    30
# 12    30
# 13    41
# 14    44
# 15    27
# 16    32
# 17    26
# 18    19
# 19    10
# dtype: int64

# %%
df.groupby('hour')['hour'].count()
# Out:
# hour
# 8      7
# 9     11
# 10    23
# 11    30
# 12    30
# 13    41
# 14    44
# 15    27
# 16    32
# 17    26
# 18    19
# 19    10
# Name: hour, dtype: int64

# %%
df['hour'].value_counts()
# Out:
# hour
# 14    44
# 13    41
# 16    32
# 12    30
# 11    30
# 15    27
# 17    26
# 10    23
# 18    19
# 9     11
# 19    10
# 8      7
# Name: count, dtype: int64

# %%
print('Транзакціі по годинам:')
df['hour'].value_counts().sort_index()
# Out:
# Транзакціі по годинам:
# hour
# 8      7
# 9     11
# 10    23
# 11    30
# 12    30
# 13    41
# 14    44
# 15    27
# 16    32
# 17    26
# 18    19
# 19    10
# Name: count, dtype: int64

# %%
print('Транзакціі по годинам (за кількістю транзакцій): \n')
df['hour'].value_counts().sort_index()
# Out:
# Транзакціі по годинам (за кількістю транзакцій):
# hour
# 8      7
# 9     11
# 10    23
# 11    30
# 12    30
# 13    41
# 14    44
# 15    27
# 16    32
# 17    26
# 18    19
# 19    10
# Name: count, dtype: int64

# %% [markdown]
# 5. Знайди день місяця з найвищим виторгом.

# %%
df['date'].dt.day
# Out:
# 0      17
# 1      13
# 2       1
# 3       2
# 4       9
#        ..
# 295     8
# 296     5
# 297     4
# 298    24
# 299    31
# Name: date, Length: 300, dtype: int32

# %%
df['day'] = df['date'].dt.day
best_day = df.groupby('day')['total_uah'].sum().idxmax()
best_revenue = df.groupby('day')['total_uah'].sum().max()

print(f'Найкращий день: {best_day} березня - {best_revenue} грн.')
# Out:
# Найкращий день: 2 березня - 3371 грн.

# %% [markdown]
# **Висновок**:
# найприбутковіша категорія - "М'ясо та риба" з виручкою 25.223 грн (висока ціна)
#
# але найчастіше купують кефір (63шт.), сосиски (61шт.) та йогурт (57шт.).
#
# Пікові години: активний продаж починаються з 11 ранку, пік клієнтів з 13 по 14 годину.
#
# Ті, хто платять карткою мають більший чек ніж ті, хто платить готівкою.

# %% [markdown]
# ### Блок 4 - Нові стовпці та трансформація

# %% [markdown]
# Додай стовпець revenue_share - частка виторгу кожної транзакції від загального виторгу (у відсотках).

# %%
total_revenue = df.total_uah.sum()
df['revenue_share'] = (df.total_uah / total_revenue * 100).round(4)

df[['product', 'total_uah', 'revenue_share']].head()
# Out:
#        product  total_uah  revenue_share
# 0      Круасан         72         0.1284
# 1  Кава мелена        465         0.8290
# 2       Яблука         45         0.0802
# 3     Риба хек        360         0.6418
# 4       Йогурт        150         0.2674

# %% [markdown]
# Додай стовпець age_group:
#
#     'Молодь' - до 30 років
#     'Середній вік' - 30–50 років
#     'Старші' - понад 50 років

# %%
df['age_group'] = pd.cut(
    df['customer_age'],
    bins=[0, 30, 50, 100],
    labels=['Молодь', 'Cередній вік', 'Старші'],
    right=False # [0, 30), [30, 50), [50, 100)
)

print(f'Розподіл по віковим групам:\n')
# df.head()
df.age_group.value_counts()
# Out:
# Розподіл по віковим групам:
# age_group
# Cередній вік    120
# Старші          111
# Молодь           69
# Name: count, dtype: int64

# %% [markdown]
# Додай стовпець weekday - день тижня з колонки date.

# %%
df['weekday'] = df.date.dt.day_name()
print('Транзакція по дням тижня:\n')
df.weekday.value_counts()
# Out:
# Транзакція по дням тижня:
# weekday
# Sunday       55
# Saturday     51
# Friday       48
# Tuesday      43
# Wednesday    35
# Monday       35
# Thursday     33
# Name: count, dtype: int64

# %% [markdown]
# Додай булевий стовпець is_big_purchase - True, якщо total_uah > 300.

# %%
df['is_big_purchase'] = df.total_uah > 300
pct = df['is_big_purchase'].mean() * 100
print(f'Частка \'великих\' покупок (> 300) {pct:.1f}%')
# Out:
# Частка 'великих' покупок (> 300) 19.3%

# %%
# Розподіл по віковим групам
print(f'Середній чек по віковим групам: ')
df.groupby('age_group', observed=True)['total_uah'].mean().round(2)
# Out:
# Середній чек по віковим групам:
# age_group
# Молодь          157.72
# Cередній вік    196.61
# Старші          194.73
# Name: total_uah, dtype: float64

# %% [markdown]
# *** Висновок:

# %% [markdown]
# ### Блок 5 - Візуалізація ###

# %% [markdown]
# Стовпчаста діаграма - виторг по категоріях.

# %%
df
# Out:
#      transaction_id       date  hour         category            product  \
# 0              1001 2024-03-17    17  Хліб та випічка            Круасан
# 1              1002 2024-03-13    14            Напої        Кава мелена
# 2              1003 2024-03-01    18  Овочі та фрукти             Яблука
# 3              1004 2024-03-02     8    М'ясо та риба           Риба хек
# 4              1005 2024-03-09    19          Молочне             Йогурт
# ..              ...        ...   ...              ...                ...
# 295            1296 2024-03-08    10    М'ясо та риба            Сосиски
# 296            1297 2024-03-05    13  Овочі та фрукти             Морква
# 297            1298 2024-03-04    11          Молочне          Молоко 1л
# 298            1299 2024-03-24    14    М'ясо та риба            Ковбаса
# 299            1300 2024-03-31    10          Молочне  Сир кисломолочний
#
#      quantity  price_uah  customer_age  payment  total_uah  day  \
# 0           4         18            28  Готівка         72   17
# 1           3        155            40   Картка        465   13
# 2           1         45            43   Картка         45    1
# 3           3        120            51  Готівка        360    2
# 4           5         30            63   Картка        150    9
# ..        ...        ...           ...      ...        ...  ...
# 295         4         98            48  Готівка        392    8
# 296         5         15            28  Телефон         75    5
# 297         3         38            27   Картка        114    4
# 298         1        145            20  Готівка        145   24
# 299         3         55            31  Телефон        165   31
#
#      revenue_share     age_group    weekday  is_big_purchase
# 0           0.1284        Молодь     Sunday            False
# 1           0.8290  Cередній вік  Wednesday             True
# 2           0.0802  Cередній вік     Friday            False
# 3           0.6418        Старші   Saturday             True
# 4           0.2674        Старші   Saturday            False
# ..             ...           ...        ...              ...
# 295         0.6989  Cередній вік     Friday             True
# 296         0.1337        Молодь    Tuesday            False
# 297         0.2032        Молодь     Monday            False
# 298         0.2585        Молодь     Sunday            False
# 299         0.2942  Cередній вік     Sunday            False
#
# [300 rows x 15 columns]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7, 3))
# df.category.value_counts().plot(kind='bar')
df.groupby('category')['total_uah'].sum().plot(kind='bar')

plt.title('Виторг по категоріях')
plt.xlabel('Категорії')
plt.ylabel('Виторг (total_uah)')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# Горизонтальна стовпчаста - топ-10 товарів за виторгом.

# %%
fig = plt.figure(figsize=(10, 3))

top10_revenue = (
    df.groupby('product')['total_uah']
    .sum()
    .sort_values(ascending=True)
    .tail(10)
)

top10_revenue.plot(
    kind='barh',
    color='#1db596',
    edgecolor='darkblue'
)

plt.title('Топ-10 товарів за виторгом')
plt.grid()
plt.ylabel('товари')
plt.xlabel('виторг')
# Out:
# Text(0.5, 0, 'виторг')

# %% [markdown]
# Кругова діаграма - розподіл способів оплати.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

payment_count = df.payment.value_counts()

ax.pie(
    payment_count,
    labels=payment_count.index,
    autopct='%1.1f%%'
)

plt.title('Розподіл способів оплати')
ax.set_title('Розподіл способів оплати')

# %% [markdown]
# Лінійний графік - виторг по днях березня.

# %% [markdown]
# Гістограма - розподіл customer_age.
